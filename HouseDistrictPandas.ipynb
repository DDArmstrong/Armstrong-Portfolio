# %% [markdown]
# <a href="https://colab.research.google.com/github/DDArmstrong/Armstrong-Portfolio/blob/master/HouseDistrictPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()

# with open('HouseDistrictData', 'w', newline='') as csvfile:
#   data = pd.read_csv("/content/drive/HouseDistrictData.csv")
# Out:
#      <input type="file" id="files-e1b80224-5942-4b81-b8cc-de10c5de07e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e1b80224-5942-4b81-b8cc-de10c5de07e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('HouseDistrictData.csv', header = [0])
# using groupby function with aggregation
# to get mean, min and max values
result = df.groupby('State').agg({'2020Margin': ['mean', 'min', 'max']})
print(result)
# Out:
#                2020Margin
#                      mean    min    max
# State
# Alabama         -0.245857 -0.634  0.423
# Alaska          -0.101000 -0.101 -0.101
# Arizona          0.044444 -0.374  0.490
# Arkansas        -0.287000 -0.412 -0.088
# California       0.296358 -0.166  0.799
# Colorado         0.130429 -0.158  0.535
# Connecticut      0.201000  0.107  0.297
# Delaware         0.190000  0.190  0.190
# Florida         -0.014926 -0.350  0.552
# Georgia          0.000571 -0.540  0.736
# Hawaii           0.294500  0.293  0.296
# Idaho           -0.302500 -0.370 -0.235
# Illinois         0.183833 -0.463  0.742
# Indiana         -0.156889 -0.397  0.276
# Iowa            -0.086250 -0.270 -0.001
# Kansas          -0.169250 -0.416  0.106
# Kentucky        -0.274333 -0.615  0.219
# Louisiana       -0.179667 -0.379  0.523
# Maine            0.078000 -0.075  0.231
# Maryland         0.342125 -0.197  0.599
# Massachusetts    0.345333  0.176  0.720
# ...
