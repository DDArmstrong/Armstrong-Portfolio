# %% [markdown]
# <a href="https://colab.research.google.com/github/DDArmstrong/Armstrong-Portfolio/blob/master/HouseDistrictPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()

# with open('Citywide_Payroll_Data__Fiscal_Year_.csv', 'w', newline='') as csvfile:
# data = pd.read_csv("/content/drive/Citywide_Payroll_Data__Fiscal_Year_.csv")
# Out:
#      <input type="file" id="files-309fe503-7e03-409e-8da3-3928f507899d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-309fe503-7e03-409e-8da3-3928f507899d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('HouseDistrictData.csv')
# print(df.to_string())
# Out:
#      Index StateDistrict State_Abbr           State  District  Population  Pct_M  Pct_F  Pct_H  Pct_W  Pct_B  Pct_A  Pct_NA  Pct_PI  Pct_O  Med_House_Inc  HS_Grad  Coll_Grad                 2020_Incumb 2020_Incumb_Party  2020_Biden  2020_Trump  2020_Margin
# 0       39         CA-18         CA      California        18      749621  0.498  0.502  0.168  0.511  0.018  0.266   0.007   0.003  0.195         146441    0.944      0.646                  Anna Eshoo                 D       0.764       0.213        0.551
# 1       38         CA-17         CA      California        17      783151  0.512  0.488  0.154  0.218  0.019  0.589   0.007   0.004  0.163         142408    0.918      0.600                   Ro Khanna                 D       0.725       0.255        0.470
# ...
